# %%
# %load_ext autoreload

# %%
import sys
import pickle
from multiprocessing import active_children
from pathlib import Path
import SimpleITK as sitk
# %autoreload 2
from ndbioimage import Imread, ReaderNotFoundError
import tifffile
import re
from ome_types import from_xml, model

# %%
test_im_path = Path(r"y:\Lab Notebooks\Ike\001-1\0001-1_FIB_LAM_GLA001-MaxIP_fn1.ome.tif")
path = test_im_path

# %%
with Imread(path) as im:
    print("thing")
# Out:
# <class 'ndbioimage.readers.cziread.Reader'>
# <class 'ndbioimage.readers.nd2read.Reader'>
# <class 'ndbioimage.readers.tifread.Reader'>
# <class 'ndbioimage.readers.ometifread.Reader'>
# thing

# %%
abc.ndim
# Out:
# 4

# %%
model.OME(y)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[51], line 1
# ----> 1 model.XMLAnnotation(y)
#
# TypeError: KindMixin.__init__() takes 1 positional argument but 2 were given

# %%
path.stem
# Out:
# '0001-1_FIB_LAM_GLA001-MaxIP_fn1.ome'

# %%
from ome_types import from_xml
from_xml(x.ome_metadata).model
# Out:
# {'rights': None,
#  'projects': [],
#  'datasets': [],
#  'folders': [],
#  'experiments': [],
#  'plates': [],
#  'screens': [],
#  'experimenters': [],
#  'experimenter_groups': [],
#  'instruments': [{'microscope': {'manufacturer': None,
#     'model': 'Ti2 Microscope',
#     'serial_number': None,
#     'lot_number': None,
#     'type': None,
#     'kind': 'microscope'},
#    'generic_excitation_sources': [],
#    'light_emitting_diodes': [],
#    'filaments': [],
#    'arcs': [],
#    'lasers': [{'manufacturer': None,
#      'model': 'LUN-F',
#      'serial_number': None,
#      'lot_number': None,
#      'annotation_refs': [],
#      'id': 'LightSource:0',
#      'power': 0.0,
#      'power_unit': <UnitsPower.MILLIWATT: 'mW'>,
#      'pump': None,
#      'type': None,
#      'laser_medium': None,
#      'wavelength': 561.0,
#      'wavelength_unit': <UnitsLength.NANOMETER: 'nm'>,
#      'frequency_multiplication': None,
#      'tuneable': None,
#      'pulse': None,
# ...
